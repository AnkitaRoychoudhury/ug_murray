# %% [markdown]
# # WELCOME to the SBTools bootcamp
#
# # SBTools: Synthetic Biology modeling and analysis Tools
#
# ## Lecturers and TAs: John Marken, Ayush Pandey, William Poole, Rory Williams, Liana Merk, Manisha Kapasiawala, Ankita Roychoudhury, Sophie Walton
#
# ## Bootcamp webpage: http://www.cds.caltech.edu/~murray/wiki/index.php?title=SBtools_Bootcamp,_June_2020
#
# ## Bootcamp Slack: https://join.slack.com/t/sbtools/shared_invite/zt-f2mcj9as-dxb~Krkjtg~wnLl3bvKndg

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Overview:
#
# 1. Tuesday and Wednesday : BioCRNpyler and Bioscrape basics and getting started
# 2. Thursday and Friday : BioCRNpyler advanced modeling tools
# 3. Next week : Sub-SBML, Gro, Bioscrape Parameter Inference, and Lineages.

# %% [markdown]
# # Installation:
#
# For today's lectures, we will be using
# * Bioscrape
# * BioCRNpyler
#
# If you have these installed already - Great!
#
# If not - Please get in touch with one of the TAs asap and get started. Post your issues on Slack.

# %% [markdown]
# We have the next ~30 minutes to get setup:
#
# * Download and install Anaconda for Python v3.6+
# * Download and install Git desktop / Git for version tracking
# * Bioscrape installation (to be used as a simulator)
# * BioCRNpyler installation (to be used as the modeling tool)
#
#
# Suggested breakout rooms:
#
# 1. Detailed discussion of Python packages, Github, along with detailed installation intructions of Anaconda, Bioscrape etc.
# 2. Windows package installation issues (Anaconda, Bioscrape, Cython, C++ compiler)
# 3. Linux and Mac installation issues (Anaconda, Bioscrape, BioCRNpyler)
# 4. For those who are all set: Developer overview of tools (version tracking, contributing to packages, etc.)

# %% [markdown]
# A selected list of tools applicable for modeling and analysis of synthetic biological circuits:
#
# * Model building tools: [BioCRNpyler](https://github.com/BuildACell/biocrnpyler) (Python), [Tellurium](http://tellurium.analogmachine.org/) (Python), [Sub-SBML](https://github.com/BuildACell/subsbml) (Python), [iBioSim](https://async.ece.utah.edu/tools/ibiosim/) (GUI), [MATLAB SimBiology](https://www.mathworks.com/products/simbiology.html)
# * Model simulation tools: [bioscrape](https://github.com/biocircuits/bioscrape/) (Python), [COPASI](http://copasi.org/) (GUI), [LibRoadRunner](http://libroadrunner.org/) (Python), [MATLAB SimBiology](https://www.mathworks.com/products/simbiology.html)
# * Analysis tools: [bioscrape inference](https://github.com/biocircuits/bioscrape/) (Python), [COPASI](http://copasi.org/) (GUI), [ABC-SysBio](http://www.theosysbio.bio.ic.ac.uk/resources/abc-sysbio/) (Python)
#
# Follow [this link](http://sbml.org/SBML_Software_Guide/SBML_Software_Summary) for detailed descriptions of various software other software tools.
