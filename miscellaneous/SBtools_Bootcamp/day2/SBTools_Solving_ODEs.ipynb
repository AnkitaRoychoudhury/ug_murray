# %% [markdown]
# # SBTools: ODE solving
# ## Solving Ordinary Differential Equations using Python
#
# ### Consider the Lotka–Volterra ordinary differential equation example:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Writing ODEs using Python functions

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams["figure.dpi"] = 100
rcParams["font.size"] = 20

# %%
import numpy as np
alpha = 1.0
beta = 0.1
delta = 0.5
gamma = 1.75

# X = [x, y]
def dX_dt(X, t=0):
    x = X[0]
    y = X[1]
    # Returns the ODE right-hand side (RHS) 
    dxdt = alpha * x -   beta * x * y
    dydt = delta * x * y - gamma * y
    return np.array([dxdt, dydt])

# %% [markdown]
# # Integrating ODEs using Python Scipy
#
# For more information: refer to the [official Scipy documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.odeint.html) for `odeint`.

# %%
from scipy.integrate import odeint
timepoints = np.linspace(0, 15, 1000)  
X0 = np.array([10, 5]) # initials conditions: x[0] = 10 and y[0] = 5
X, infodict = odeint(dX_dt, X0, timepoints, full_output = True)
infodict['message']
# Out:
# 'Integration successful.'

# %% [markdown]
# # Plot your results using Python matplotlib

# %%
import matplotlib.pyplot as plt
x, y = X.T
plt.figure()
plt.plot(timepoints, x, 'r-', lw = 4, label='x')
plt.plot(timepoints, y  , 'b-', lw = 4, label='y')
plt.legend(loc = "best")
plt.xlabel('Time')
plt.ylabel('population')
plt.title('Evolution of populations');

# %% [markdown]
# # Exercises:
#
# 1. (Beginner) Write an ODE model for the simple CRN shown in the lecture earlier, simulate using odeint, and compare the results with a BioCRNpyler model simulation of the same CRN.
# 2. (Advanced) Compute the Jacobian of the Lotka-Volterra ODE system and analyze the stability of the system based on the eigen values of the Jacobian (negative eigen values imply stability, imaginary eigen values could imply limit cycles - more [here](https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations)). Check this result by plotting a phase portrait for the system (a x vs y plot in two dimensions).

# %% [markdown]
# References (used in this noteboook):
# 1. https://scipy-cookbook.readthedocs.io/items/LoktaVolterraTutorial.html
# 2. https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations
