# %% [markdown]
# # Predicted Figures for RM Meeting
# 10.11.2020

# %% [markdown]
# ## ATP Calibration Curve

# %%
import bokeh.io
import bokeh.plotting

bokeh.io.output_notebook()

import numpy as np
import colorcet
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
p = bokeh.plotting.figure(width = 350, height = 300, title = 'EXAMPLE Figure of ATP Calibration Curve',
                         x_axis_label = '[ATP]',
                         y_axis_label = 'Biotek Fluorescence Levels')
x_vals = np.linspace(0,100,100)
y_vals = np.linspace(1,100,100)
p.line(x_vals, y_vals, line_width = 4)
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="56371a75-5a16-41a8-9af2-5faf8b00b265" data-root-id="1513"></div>
