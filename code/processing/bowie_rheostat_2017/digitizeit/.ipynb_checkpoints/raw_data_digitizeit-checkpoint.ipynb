# %% [markdown]
# # Use Digitizeit to extract data from Opgenorth Paper
# 6.26.2020 <br>
# Ankita Roychoudhury <br>
# **'A molecular rheostat maintains ATP levels to drive a synthetic biochemistry system'** <br>
# Paul H Opgenorth, Tyler P Korman, Liviu Iancu, James U Bowie <br>
# Nature 3 July 2017

# %%
# Import cell
import numpy as np
import pandas as pd
# import scipy.special as sp
# import scipy.optimize
# from scipy.optimize import curve_fit
# import scipy.integrate
# from scipy.integrate import odeint

# from tqdm import tqdm
# import panel as pn

import bokeh.io
import bokeh.plotting
# import bokeh_catplot

# import bebi103

# import holoviews as hv
bokeh.io.output_notebook()
# hv.extension('bokeh')

# bebi103.hv.set_defaults()
# pn.extension()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Digitizeit link: https://automeris.io/WebPlotDigitizer/

# %% [markdown]
# Plots from paper:

# %% [markdown]
# <div style="width: 500px; margin: auto">
#
# ![glucose,isobutanol](bowie_paper_gluc_isob_image.png)
#
# </div>

# %% [markdown]
# <div style="width: 500px; margin: auto">
#
# ![atp](bowie_paper_atp_image.png)
#
# </div>

# %% [markdown]
# Now, we use Digitize it to extract what seem to be the data points in this system. Since we do not yet have access to the experimental data, we will only extract the mean values for the 5 data points. It is concerning that there are large SEM bars and so few data points. We cannot truly know what is going on between the time points.

# %% [markdown]
# Data files are stored in this folder, under the names: gluc_data_digitizeit.csv, isob_data_digitizeit.csv, atp_data_digitizeit.csv

# %% [markdown]
# ## Take a look at the extracted data
# ### Isobutanol

# %%
# Load in csv
df_iso_raw = pd.read_csv('isob_data_digitizeit.csv')

# Take a look
df_iso_raw.head()
# Out:
#            0   2.7586206896551744
# 0   6.979866           113.103448
# 1  25.234899           256.551724
# 2  48.859060           325.517241
# 3  72.483221           328.275862

# %%
# Do some wrangling, include first data points

# Get first data point
iso_x0 = df_iso_raw.columns[0]
iso_y0 = df_iso_raw.columns[1]

# Add (x0,y0) to own dataframe
df_iso_0 = pd.DataFrame({'x':iso_x0, 'y':iso_y0}, index = [0])

# Rename df_isob columns
df_iso_raw.columns = ['x', 'y']

# Concatenate two dataframes into one
df_iso = pd.concat([df_iso_0, df_iso_raw], ignore_index = True)

# Take a look
df_iso.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-6aee1bc89b44> in <module>
#       6
#       7 # Add (x0,y0) to own dataframe
# ----> 8 df_iso_0 = pd.DataFrame({'x':iso_x0, 'y':iso_y0})
#       9
#      10 # Rename df_isob columns
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     353
#     354         if not indexes and not raw_lengths:
# --> 355             raise ValueError("If using all scalar values, you must pass an index")
#     356
#     357         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
new_row_atp = pd.DataFrame({'x':x0_atp, 'y':x1_atp}, index =[0])
df_col_atp = df_atp
df_col_atp.columns = ['x', 'y']
df_new_atp = pd.concat([new_row_atp, df_col_atp], ignore_index=True)
